# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathssa/Machine-Learning/blob/main/cardekho_selling_price_predict_kaggle_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('car data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
### There is no null value
df.head()
# Out:
#   Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0     ritz  2014           3.35  ...       Dealer        Manual     0
# 1      sx4  2013           4.75  ...       Dealer        Manual     0
# 2     ciaz  2017           7.25  ...       Dealer        Manual     0
# 3  wagon r  2011           2.85  ...       Dealer        Manual     0
# 4    swift  2014           4.60  ...       Dealer        Manual     0
#
# [5 rows x 9 columns]

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0     ritz  2014           3.35  ...       Dealer        Manual     0
# 1      sx4  2013           4.75  ...       Dealer        Manual     0
# 2     ciaz  2017           7.25  ...       Dealer        Manual     0
# 3  wagon r  2011           2.85  ...       Dealer        Manual     0
# 4    swift  2014           4.60  ...       Dealer        Manual     0
#
# [5 rows x 9 columns]

# %%
from datetime import date
today = date.today()
current_year = today.year
print(current_year)
# Out:
# 2022

# %%
df['current_year'] = current_year
df.head(5)
# Out:
#   Car_Name  Year  Selling_Price  ...  Transmission  Owner current_year
# 0     ritz  2014           3.35  ...        Manual      0         2022
# 1      sx4  2013           4.75  ...        Manual      0         2022
# 2     ciaz  2017           7.25  ...        Manual      0         2022
# 3  wagon r  2011           2.85  ...        Manual      0         2022
# 4    swift  2014           4.60  ...        Manual      0         2022
#
# [5 rows x 10 columns]

# %%
df['No. of Years'] = df['current_year'] - df['Year']
df.head(3)
# Out:
#   Car_Name  Year  Selling_Price  ...  Owner  current_year No. of Years
# 0     ritz  2014           3.35  ...      0          2022            8
# 1      sx4  2013           4.75  ...      0          2022            9
# 2     ciaz  2017           7.25  ...      0          2022            5
#
# [3 rows x 11 columns]

# %%
# Year and Current year is not required at this stage since we have calculate the no.of year of the car

df.drop(columns = ['Year','current_year'], inplace= True, axis =1 )

df.head(3)
# Out:
#   Car_Name  Selling_Price  Present_Price  ...  Transmission Owner No. of Years
# 0     ritz           3.35           5.59  ...        Manual     0            8
# 1      sx4           4.75           9.54  ...        Manual     0            9
# 2     ciaz           7.25           9.85  ...        Manual     0            5
#
# [3 rows x 9 columns]

# %% [markdown]
# Let's Do some EDA

# %%
numerical_features = [i for i in df.columns if df.dtypes[i]!='O']
print(numerical_features)
# Out:
# ['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'No. of Years']

# %%
categorical_features = [i for i in df.columns if df.dtypes[i]=='O']
print (categorical_features)
# Out:
# ['Car_Name', 'Fuel_Type', 'Seller_Type', 'Transmission']

# %%
### Extracting Unique features from categorical_features
for i in categorical_features:
  print ('{}:'.format(i) , df[i].unique())
# Out:
# Car_Name: ['ritz' 'sx4' 'ciaz' 'wagon r' 'swift' 'vitara brezza' 's cross'
#  'alto 800' 'ertiga' 'dzire' 'alto k10' 'ignis' '800' 'baleno' 'omni'
#  'fortuner' 'innova' 'corolla altis' 'etios cross' 'etios g' 'etios liva'
#  'corolla' 'etios gd' 'camry' 'land cruiser' 'Royal Enfield Thunder 500'
#  'UM Renegade Mojave' 'KTM RC200' 'Bajaj Dominar 400'
#  'Royal Enfield Classic 350' 'KTM RC390' 'Hyosung GT250R'
#  'Royal Enfield Thunder 350' 'KTM 390 Duke ' 'Mahindra Mojo XT300'
#  'Bajaj Pulsar RS200' 'Royal Enfield Bullet 350'
#  'Royal Enfield Classic 500' 'Bajaj Avenger 220' 'Bajaj Avenger 150'
#  'Honda CB Hornet 160R' 'Yamaha FZ S V 2.0' 'Yamaha FZ 16'
#  'TVS Apache RTR 160' 'Bajaj Pulsar 150' 'Honda CBR 150' 'Hero Extreme'
#  'Bajaj Avenger 220 dtsi' 'Bajaj Avenger 150 street' 'Yamaha FZ  v 2.0'
#  'Bajaj Pulsar  NS 200' 'Bajaj Pulsar 220 F' 'TVS Apache RTR 180'
#  'Hero Passion X pro' 'Bajaj Pulsar NS 200' 'Yamaha Fazer '
#  'Honda Activa 4G' 'TVS Sport ' 'Honda Dream Yuga '
#  'Bajaj Avenger Street 220' 'Hero Splender iSmart' 'Activa 3g'
#  'Hero Passion Pro' 'Honda CB Trigger' 'Yamaha FZ S '
#  'Bajaj Pulsar 135 LS' 'Activa 4g' 'Honda CB Unicorn'
#  'Hero Honda CBZ extreme' 'Honda Karizma' 'Honda Activa 125' 'TVS Jupyter'
#  'Hero Honda Passion Pro' 'Hero Splender Plus' 'Honda CB Shine'
#  'Bajaj Discover 100' 'Suzuki Access 125' 'TVS Wego' 'Honda CB twister'
#  'Hero Glamour' 'Hero Super Splendor' 'Bajaj Discover 125' 'Hero Hunk'
#  'Hero  Ignitor Disc' 'Hero  CBZ Xtreme' 'Bajaj  ct 100' 'i20' 'grand i10'
#  'i10' 'eon' 'xcent' 'elantra' 'creta' 'verna' 'city' 'brio' 'amaze'
#  'jazz']
# Fuel_Type: ['Petrol' 'Diesel' 'CNG']
# Seller_Type: ['Dealer' 'Individual']
# Transmission: ['Manual' 'Automatic']

# %%
### Let's see count of Fuel_varient used accross various car model
df['Car_Name'].groupby(df['Fuel_Type']).count().sort_values(ascending=False)
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: Car_Name, dtype: int64

# %%
### Let's see count of Transmission used accross various car model

df['Car_Name'].groupby(df['Transmission']).count().sort_values(ascending=False)
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: Car_Name, dtype: int64

# %%
### Let's see count of Seller_type used accross various car model

df['Car_Name'].groupby(df['Seller_Type']).count().sort_values(ascending=False)
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: Car_Name, dtype: int64

# %%
sns.pairplot(df)

# %%
### Top 5 Model using Fuel_Type

plt.figure (figsize=(10,7)) 
sns.countplot(y='Car_Name', hue='Fuel_Type', data=df, order=df['Car_Name'].value_counts().iloc[:5].index)

# %%
### Top 5 Model using Transmission

plt.figure (figsize=(10,7))
sns.countplot(y='Car_Name', hue='Transmission', data=df, order=df['Car_Name'].value_counts().iloc[:5].index)

# %%
###LEt's see Top 10 car model's selling price using Fuel_type
fig, ax = plt.subplots(figsize=(15,6))
ax = sns.barplot(y='Selling_Price', x='Car_Name', data=df, hue='Fuel_Type', order=df['Car_Name'].value_counts().iloc[:10].index)

# %%
### Let's see whether Kms_Driven affects selling Price
fig, ax = plt.subplots(figsize=(15,6))
ax = sns.barplot(y='Selling_Price', x='Kms_Driven', data=df, order=df['Kms_Driven'].sort_values(ascending=True).value_counts().iloc[:10].index )

# %%
###Box plot to find outliers

fig, ax = plt.subplots(figsize=(20,3))
ax = sns.boxplot(x="Kms_Driven", y="Selling_Price", data=df, order=df['Kms_Driven'].sort_values(ascending=True).value_counts().iloc[:10].index)

# %%
print(df.corr())
# Out:
#                Selling_Price  Present_Price  Kms_Driven     Owner  No. of Years
# Selling_Price       1.000000       0.878983    0.029187 -0.088344     -0.236141
# Present_Price       0.878983       1.000000    0.203647  0.008057      0.047584
# Kms_Driven          0.029187       0.203647    1.000000  0.089216      0.524342
# Owner              -0.088344       0.008057    0.089216  1.000000      0.182104
# No. of Years       -0.236141       0.047584    0.524342  0.182104      1.000000

# %%
dataplot = sns.heatmap( df.corr(), cmap="YlGnBu", annot= True )
plt.show()

# %% [markdown]
# ### Feature Engineering Part

# %%
df.plot(kind='box')

# %%
sns.boxplot(df['Kms_Driven'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print
# 296     city           9.50          11.60  ...        Manual     0            6
# 297     brio           4.00           5.90  ...        Manual     0            7
# 298     city           3.35          11.00  ...        Manual     0           13
# 299     city          11.50          12.50  ...        Manual     0            5
# 300     brio           5.30           5.90  ...        Manual     0            6
#
# [298 rows x 9 columns]

# %%
print('New Shape:',df.shape)
# Out:
# New Shape: (298, 9)

# %% [markdown]
# ### Feature Selection

# %%
df.drop(['Car_Name'], inplace=True, axis=1)

# %%
df.head(10)
# Out:
#    Selling_Price  Present_Price  Kms_Driven  ... Transmission Owner No. of Years
# 0           3.35           5.59       27000  ...       Manual     0            8
# 1           4.75           9.54       43000  ...       Manual     0            9
# 2           7.25           9.85        6900  ...       Manual     0            5
# 3           2.85           4.15        5200  ...       Manual     0           11
# 4           4.60           6.87       42450  ...       Manual     0            8
# 5           9.25           9.83        2071  ...       Manual     0            4
# 6           6.75           8.12       18796  ...       Manual     0            7
# 7           6.50           8.61       33429  ...       Manual     0            7
# 8           8.75           8.89       20273  ...       Manual     0            6
# 9           7.45           8.92       42367  ...       Manual     0            7
#
# [10 rows x 8 columns]

# %%
df = pd.get_dummies(df, drop_first=True)
df
# Out:
#      Selling_Price  Present_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0             3.35           5.59  ...                       0                    1
# 1             4.75           9.54  ...                       0                    1
# 2             7.25           9.85  ...                       0                    1
# 3             2.85           4.15  ...                       0                    1
# 4             4.60           6.87  ...                       0                    1
# ..             ...            ...  ...                     ...                  ...
# 296           9.50          11.60  ...                       0                    1
# 297           4.00           5.90  ...                       0                    1
# 298           3.35          11.00  ...                       0                    1
# 299          11.50          12.50  ...                       0                    1
# 300           5.30           5.90  ...                       0                    1
#
# [298 rows x 9 columns]

# %%
X = df.iloc[:,1:]
y = df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split, cross_val_score, ShuffleSplit
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import xgboost as xgb

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (238, 8)
# (60, 8)

# %%
def final_predictions(model, name):
    new_model = model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print("============= %s and Shuffle Split =============" %name)
    print("Accuracy: %f" %(r2_score(y_test, y_pred)))
    print("MSE: %f" %(mean_squared_error(y_test, y_pred)))
    print("MAE: %f" %(mean_absolute_error(y_test, y_pred)))
    
    new_model = model.fit(X, y)
    cv = ShuffleSplit(n_splits=5, test_size=0.3, random_state=0)
    cvs = cross_val_score(model, X, y, cv=cv)
    print('Shuffle and cross validate: %s \nAverage: %.2f' %(cvs, cvs.mean()))

# %%
### Linear Regression
lr_model = LinearRegression()
final_predictions(lr_model, 'Linear Regression')
# Out:
# ============= Linear Regression and Shuffle Split =============
# Accuracy: 0.880145
# MSE: 4.601267
# MAE: 1.221099
# Shuffle and cross validate: [0.87023649 0.84521491 0.84587052 0.88933067 0.89211685]
# Average: 0.87

# %%
dt_model = DecisionTreeRegressor(random_state=0)
final_predictions(dt_model, 'Decision Tree Regressor')
# Out:
# ============= Decision Tree Regressor and Shuffle Split =============
# Accuracy: 0.928993
# MSE: 2.725978
# MAE: 0.833167
# Shuffle and cross validate: [0.9376827  0.91074574 0.90171122 0.94251023 0.96505657]
# Average: 0.93

# %%
rf_model = RandomForestRegressor(random_state=0)
final_predictions(rf_model, 'Random Forest Regressor')
# Out:
# ============= Random Forest Regressor and Shuffle Split =============
# Accuracy: 0.923269
# MSE: 2.945743
# MAE: 0.759578
# Shuffle and cross validate: [0.92617933 0.91831821 0.91724233 0.96070956 0.95153947]
# Average: 0.93

# %%
###Hyperparameter tuning (Random Search)

from itertools import product
import random

#params
booster = 'gbtree'
silent = 0

eta = [0.01,0.1,0.2,0.3]  #learning rate in gbm
min_child_weight = [1,2,0.5]  #minimum sum of weights of all observations required in a child
max_depth = [3,6,8]  #maximum depth of the tree
gamma = [0,1]  #a split will occur only when reduction in loss function > gamma 
subsample = [0.5,0.7,1] #fraction of rows to be sampled to make a decision tree
colsample_bytree = [0.5,0.7,1] #fraction of columns to be sampled to make a decision tree
# lambda_ = [0.4,0.8,1] #L2 regularization weights
alpha = [0,1]  #L1 reg weights



params =  [eta,min_child_weight,max_depth,gamma,subsample,colsample_bytree,alpha]
parameters = list(product(*params))
parameters = random.sample(parameters,100)
len(parameters)


min_rmse = float('inf')
best_params = parameters[0]
for p in parameters:
    eta = p[0]
    min_child_weight = p[1]
    max_depth = p[2]
    gamma = p[3]
    subsample = p[4]
    colsample_bytree = p[5]
    alpha = p[6]

    print('Random Search On Hyperparamters Xgboost')
    print(f"Fitting params -> eta: {eta}, min_child_weight: {min_child_weight} ,\
    max_depth:{max_depth}, gamma: {gamma}, subsample : {subsample},\
    col_sample_bytree: {colsample_bytree:},alpha: {alpha}")
    
    model = xgb.XGBRegressor(random_state=42,booster = 'gbtree',verbosity=0,eta=eta,
                             min_child_weight=min_child_weight,max_depth=max_depth,gamma=gamma,
                             subsample=subsample,colsample_bytree=colsample_bytree,alpha=alpha)
    
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    
    y_pred_rmse = mean_squared_error(y_test,y_pred,squared=False)
    
    
    print(f'Train rmse: {y_pred_rmse}')
    
    
    if y_pred_rmse < min_rmse:
        min_rmse = y_pred_rmse
        best_params = p
        
    print('--'*50)
    

    
print(f'Found following best parameters: eta: {best_params[0]},\
min_child_weight: {best_params[1]} , max_depth:{best_params[2]}, gamma: {best_params[3]}, subsample : {best_params[4]}, \
col_sample_bytree: {best_params[5]},alpha: {best_params[6]} with validation loss {min_rmse}')
# Out:
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 1 ,    max_depth:8, gamma: 0, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 2.066982271474193
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 0.5 ,    max_depth:3, gamma: 1, subsample : 1,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 1.963222311583197
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 2 ,    max_depth:8, gamma: 0, subsample : 1,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 1.867202416995112
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 1 ,    max_depth:8, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 2.0343624372822955
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 2 ,    max_depth:6, gamma: 0, subsample : 1,    col_sample_bytree: 1,alpha: 1
# Train rmse: 1.574362848223125
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 0.5 ,    max_depth:6, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.6757293068439656
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 0.5 ,    max_depth:6, gamma: 0, subsample : 0.7,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 1.9388484932025218
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 2 ,    max_depth:3, gamma: 1, subsample : 1,    col_sample_bytree: 1,alpha: 1
# Train rmse: 1.6751711363901376
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 1 ,    max_depth:8, gamma: 0, subsample : 0.5,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.4336164159702993
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 0.5 ,    max_depth:8, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.7559276463754265
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 2 ,    max_depth:6, gamma: 0, subsample : 0.7,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.3728663396383955
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 2 ,    max_depth:3, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 1.5500122786851078
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 0.5 ,    max_depth:3, gamma: 1, subsample : 0.5,    col_sample_bytree: 1,alpha: 1
# Train rmse: 1.5147068059676656
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 1 ,    max_depth:3, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.7,alpha: 0
# Train rmse: 1.7003674563298319
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 1 ,    max_depth:3, gamma: 0, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 0
# Train rmse: 1.6229327154362825
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 2 ,    max_depth:6, gamma: 0, subsample : 0.7,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 1.4761724322376082
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 2 ,    max_depth:3, gamma: 1, subsample : 0.5,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.219180548813433
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 0.5 ,    max_depth:6, gamma: 0, subsample : 0.7,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 1.9388484932025218
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 0.5 ,    max_depth:6, gamma: 1, subsample : 1,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.8655492775225808
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 1 ,    max_depth:6, gamma: 0, subsample : 1,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 2.1909275067810383
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 2 ,    max_depth:8, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 1.5852047474936939
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 0.5 ,    max_depth:3, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.5925241162696022
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 2 ,    max_depth:8, gamma: 0, subsample : 0.5,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.2756936100525826
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 0.5 ,    max_depth:3, gamma: 0, subsample : 0.7,    col_sample_bytree: 1,alpha: 1
# Train rmse: 1.4866901199791716
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 1 ,    max_depth:8, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 2.0343624372822955
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 2 ,    max_depth:6, gamma: 0, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 0
# Train rmse: 1.4464814400969306
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 0.5 ,    max_depth:6, gamma: 1, subsample : 0.5,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.4293468760420012
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 1 ,    max_depth:8, gamma: 0, subsample : 1,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 2.237290604317465
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 0.5 ,    max_depth:3, gamma: 0, subsample : 0.7,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.4866901199791716
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 0.5 ,    max_depth:3, gamma: 0, subsample : 0.5,    col_sample_bytree: 0.7,alpha: 0
# Train rmse: 1.680113141343339
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 0.5 ,    max_depth:8, gamma: 1, subsample : 0.7,    col_sample_bytree: 1,alpha: 1
# Train rmse: 1.563307942748227
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 2 ,    max_depth:6, gamma: 0, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 1.559682212894595
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 0.5 ,    max_depth:6, gamma: 0, subsample : 1,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 2.1909275067810383
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 1 ,    max_depth:6, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.7250374008516498
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 1 ,    max_depth:8, gamma: 0, subsample : 1,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 2.237290604317465
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 1 ,    max_depth:6, gamma: 1, subsample : 1,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.8027667833533723
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 1 ,    max_depth:3, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 2.2008194059695287
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 2 ,    max_depth:8, gamma: 1, subsample : 0.5,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.2666008125154868
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 0.5 ,    max_depth:6, gamma: 0, subsample : 0.5,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.4460128610987328
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 1 ,    max_depth:3, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.7003674563298319
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 1 ,    max_depth:8, gamma: 0, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.6877134277822463
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 1 ,    max_depth:8, gamma: 1, subsample : 1,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.8696293137493485
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 0.5 ,    max_depth:3, gamma: 1, subsample : 1,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 1.963222311583197
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 2 ,    max_depth:8, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.4238198478963038
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 0.5 ,    max_depth:8, gamma: 1, subsample : 0.7,    col_sample_bytree: 1,alpha: 1
# Train rmse: 1.563307942748227
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 2 ,    max_depth:6, gamma: 0, subsample : 1,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.5327087488026272
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 0.5 ,    max_depth:8, gamma: 1, subsample : 0.7,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.563307942748227
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 1 ,    max_depth:6, gamma: 0, subsample : 0.5,    col_sample_bytree: 0.7,alpha: 0
# Train rmse: 1.7049067855814592
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 2 ,    max_depth:6, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 1.5486757244476923
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 1 ,    max_depth:8, gamma: 1, subsample : 0.5,    col_sample_bytree: 1,alpha: 1
# Train rmse: 1.4332686980930633
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 0.5 ,    max_depth:6, gamma: 0, subsample : 1,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 2.1909275067810383
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 1 ,    max_depth:3, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 1.864355736919093
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 2 ,    max_depth:3, gamma: 0, subsample : 0.5,    col_sample_bytree: 1,alpha: 1
# Train rmse: 1.2390610472148202
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 1 ,    max_depth:8, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 2.0343624372822955
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 0.5 ,    max_depth:3, gamma: 0, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 0
# Train rmse: 1.6229327154362825
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 0.5 ,    max_depth:8, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 2.0343624372822955
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 2 ,    max_depth:3, gamma: 0, subsample : 1,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.649602621273101
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 0.5 ,    max_depth:6, gamma: 0, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 2.047726450866969
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 0.5 ,    max_depth:3, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.7003674563298319
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 2 ,    max_depth:3, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 0
# Train rmse: 1.3822578748827492
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 2 ,    max_depth:3, gamma: 0, subsample : 1,    col_sample_bytree: 0.7,alpha: 0
# Train rmse: 1.6753892241321682
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 0.5 ,    max_depth:6, gamma: 1, subsample : 0.5,    col_sample_bytree: 1,alpha: 1
# Train rmse: 1.4293468760420012
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 0.5 ,    max_depth:8, gamma: 1, subsample : 1,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 2.160950720898878
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 2 ,    max_depth:3, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.405260935563879
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 1 ,    max_depth:6, gamma: 1, subsample : 1,    col_sample_bytree: 0.7,alpha: 0
# Train rmse: 1.8027667833533723
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 1 ,    max_depth:8, gamma: 0, subsample : 1,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 2.237290604317465
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 1 ,    max_depth:6, gamma: 1, subsample : 0.7,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.5623200624107423
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 0.5 ,    max_depth:6, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.7250374008516498
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 0.5 ,    max_depth:8, gamma: 0, subsample : 1,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 2.237290604317465
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 0.5 ,    max_depth:6, gamma: 0, subsample : 1,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.8328628932154445
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 0.5 ,    max_depth:6, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.7250374008516498
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 1 ,    max_depth:6, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 1.9098595394663882
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 0.5 ,    max_depth:3, gamma: 1, subsample : 1,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.7448946411656812
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 0.5 ,    max_depth:3, gamma: 0, subsample : 1,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.6844532820616205
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 1 ,    max_depth:8, gamma: 1, subsample : 1,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 2.160950720898878
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 1 ,    max_depth:6, gamma: 0, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 0
# Train rmse: 1.6922246676671473
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 0.5 ,    max_depth:3, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 2.2008194059695287
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 2 ,    max_depth:3, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.3822578748827492
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 2 ,    max_depth:6, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.3418490109907335
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 0.5 ,    max_depth:8, gamma: 1, subsample : 1,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.819377315872272
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 2 ,    max_depth:6, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 1.5720935497951911
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 1 ,    max_depth:8, gamma: 1, subsample : 1,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 2.160950720898878
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 1 ,    max_depth:6, gamma: 0, subsample : 1,    col_sample_bytree: 0.7,alpha: 0
# Train rmse: 1.8308323383526843
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 2 ,    max_depth:8, gamma: 0, subsample : 0.7,    col_sample_bytree: 1,alpha: 1
# Train rmse: 1.3759380153002396
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 0.5 ,    max_depth:3, gamma: 0, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 2.2111006577901606
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 2 ,    max_depth:6, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 1.5486757244476923
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 0.5 ,    max_depth:6, gamma: 0, subsample : 0.7,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 1.9388484932025218
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 2 ,    max_depth:3, gamma: 0, subsample : 1,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.6753892241321682
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 2 ,    max_depth:3, gamma: 0, subsample : 1,    col_sample_bytree: 1,alpha: 1
# Train rmse: 1.649602621273101
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 2 ,    max_depth:8, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 1.5852047474936939
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 2 ,    max_depth:8, gamma: 0, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.4960908200823837
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 1 ,    max_depth:8, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 0
# Train rmse: 1.7559276463754265
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 1 ,    max_depth:3, gamma: 0, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 2.2111006577901606
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.3, min_child_weight: 0.5 ,    max_depth:6, gamma: 1, subsample : 0.5,    col_sample_bytree: 0.7,alpha: 0
# Train rmse: 1.6757293068439656
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 2 ,    max_depth:3, gamma: 1, subsample : 0.5,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.219180548813433
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.1, min_child_weight: 2 ,    max_depth:3, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.3822578748827492
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 2 ,    max_depth:8, gamma: 1, subsample : 0.7,    col_sample_bytree: 0.5,alpha: 0
# Train rmse: 1.475904259723203
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 1 ,    max_depth:8, gamma: 0, subsample : 0.7,    col_sample_bytree: 0.7,alpha: 1
# Train rmse: 1.6877134277822463
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.2, min_child_weight: 0.5 ,    max_depth:3, gamma: 1, subsample : 1,    col_sample_bytree: 1,alpha: 0
# Train rmse: 1.7275647471701074
# ----------------------------------------------------------------------------------------------------
# Random Search On Hyperparamters Xgboost
# Fitting params -> eta: 0.01, min_child_weight: 1 ,    max_depth:8, gamma: 0, subsample : 0.5,    col_sample_bytree: 0.5,alpha: 1
# Train rmse: 2.066982271474193
# ----------------------------------------------------------------------------------------------------
# Found following best parameters: eta: 0.01,min_child_weight: 2 , max_depth:3, gamma: 1, subsample : 0.5, col_sample_bytree: 1,alpha: 0 with validation loss 1.219180548813433

# %%
###Best Params taken from Hyperparameter Tuning.

eta = best_params[0] 
min_child_weight= best_params[1] 
max_depth=best_params[2]
gamma= best_params[3]
subsample = best_params[4]
colsample_bytree= best_params[5]
alpha= best_params[6] 

xgb_model = xgb.XGBRegressor(random_state=42,booster = 'gbtree',verbosity=0,eta=eta,min_child_weight=min_child_weight,
                         max_depth=max_depth,gamma=gamma,subsample=subsample,colsample_bytree=colsample_bytree,alpha=alpha)

final_predictions(xgb_model, 'XGB Regressor')
# Out:
# ============= XGB Regressor and Shuffle Split =============
# Accuracy: 0.961282
# MSE: 1.486401
# MAE: 0.651419
# Shuffle and cross validate: [0.95068832 0.93541794 0.92522112 0.96351336 0.92488374]
# Average: 0.94
